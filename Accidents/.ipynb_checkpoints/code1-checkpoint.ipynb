# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

# %%
# This problem statement wants us to predict the Accident riks given the many signals such as the road curvature, etc

df = pd.read_csv("train.csv")

# %%
df.head(5)
# Out:
#    id road_type  num_lanes  curvature  speed_limit  lighting weather  \
# 0   0     urban          2       0.06           35  daylight   rainy
# 1   1     urban          4       0.99           35  daylight   clear
# 2   2     rural          4       0.63           70       dim   clear
# 3   3   highway          4       0.07           35       dim   rainy
# 4   4     rural          1       0.58           60  daylight   foggy
#
#    road_signs_present  public_road time_of_day  holiday  school_season  \
# 0               False         True   afternoon    False           True
# 1                True        False     evening     True           True
# 2               False         True     morning     True          False
# 3                True         True     morning    False          False
# 4               False        False     evening     True          False
#
#    num_reported_accidents  accident_risk
# 0                       1           0.13
# ...

# %%
df = df.drop(columns = 'id', axis = 1)

# %%
cat = []

for col in df.columns:
    cat.append(col)

# %%
df['road_type'].dtypes
# Out:
# dtype('O')

# %%
cat


for str in col:
    if(df[str].dtype == 'object')
# Out:
# ['road_type',
#  'num_lanes',
#  'curvature',
#  'speed_limit',
#  'lighting',
#  'weather',
#  'road_signs_present',
#  'public_road',
#  'time_of_day',
#  'holiday',
#  'school_season',
#  'num_reported_accidents',
#  'accident_risk']

# %%
df.dtypes
# Out:
# road_type                  object
# num_lanes                   int64
# curvature                 float64
# speed_limit                 int64
# lighting                   object
# weather                    object
# road_signs_present           bool
# public_road                  bool
# time_of_day                object
# holiday                      bool
# school_season                bool
# num_reported_accidents      int64
# accident_risk             float64
# dtype: object

# %%
df.head(5)
# Out:
#   road_type  num_lanes  curvature  speed_limit  lighting weather  \
# 0     urban          2       0.06           35  daylight   rainy
# 1     urban          4       0.99           35  daylight   clear
# 2     rural          4       0.63           70       dim   clear
# 3   highway          4       0.07           35       dim   rainy
# 4     rural          1       0.58           60  daylight   foggy
#
#    road_signs_present  public_road time_of_day  holiday  school_season  \
# 0               False         True   afternoon    False           True
# 1                True        False     evening     True           True
# 2               False         True     morning     True          False
# 3                True         True     morning    False          False
# 4               False        False     evening     True          False
#
#    num_reported_accidents  accident_risk
# 0                       1           0.13
# 1                       0           0.35
# ...

# %%
# Nominal Categorical values - Road_type, time_of_day

# Oridnal Categorical Values - Lighting, weather, road_signs_present, public_road, holiday, school_season

"""
We will perform OHE on nominal ones and ordinal encoding on Ordinal values
"""

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# Col for Nominal - 0, 8

# Col for Ordinal - 4,5,6,7,9,10
